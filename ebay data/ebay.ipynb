# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
# import relevant data
ebay = pd.read_csv('C:/Users/15165/Documents/531 licenses/ebay 531 cleaned python.csv')

# %%
ebay.head()
# Out:
#    sellerRating  OpenDayValue  Duration  EndDayValue   ClosePrice   OpenPrice  \
# 0           158             7         5            5         1.23        1.23
# 1          1550             5         7            5         1.23        1.23
# 2          1550             5         7            5         1.23        1.23
# 3          1550             5         7            5         1.23        1.23
# 4          1550             5         7            5         1.23        1.23
#
#    Competitive  USDClosePrice  USDOpenPrice  DollarOpen
# 0            0            1.4           1.4           1
# 1            0            1.4           1.4           1
# 2            0            1.4           1.4           1
# 3            0            1.4           1.4           1
# 4            0            1.4           1.4           1

# %%
import numpy as np; np.random.seed()
import seaborn as sns; sns.set_theme()
uniform_data = ebay
ax = sns.heatmap(uniform_data, vmin=0, vmax=1)

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
ebay.corr()
# Out:
#                sellerRating  OpenDayValue  Duration  EndDayValue   ClosePrice  \
# sellerRating       1.000000      0.160779 -0.149734    -0.008256     0.000158
# OpenDayValue       0.160779      1.000000 -0.211105     0.231501     0.084749
# Duration          -0.149734     -0.211105  1.000000     0.183044    -0.090714
# EndDayValue       -0.008256      0.231501  0.183044     1.000000     0.103732
#  ClosePrice        0.000158      0.084749 -0.090714     0.103732     1.000000
#  OpenPrice        -0.041113      0.073947 -0.085289     0.103556     0.476931
# Competitive       -0.033956      0.012524 -0.026478    -0.171190     0.178458
# USDClosePrice     -0.008580      0.081315 -0.080970     0.104787     0.997255
# USDOpenPrice      -0.044475      0.071617 -0.080130     0.105408     0.478948
# DollarOpen         0.000550      0.082336 -0.088113     0.099700     0.999470
#
#                 OpenPrice  Competitive  USDClosePrice  USDOpenPrice  \
# sellerRating    -0.041113    -0.033956      -0.008580     -0.044475
# OpenDayValue     0.073947     0.012524       0.081315      0.071617
# Duration        -0.085289    -0.026478      -0.080970     -0.080130
# EndDayValue      0.103556    -0.171190       0.104787      0.105408
#  ClosePrice      0.476931     0.178458       0.997255      0.478948
#  OpenPrice       1.000000    -0.096646       0.460868      0.999090
# Competitive     -0.096646     1.000000       0.182333     -0.095796
# USDClosePrice    0.460868     0.182333       1.000000      0.464319
# USDOpenPrice     0.999090    -0.095796       0.464319      1.000000
# DollarOpen       0.472885     0.180872       0.996906      0.474961
#
#                DollarOpen
# sellerRating     0.000550
# OpenDayValue     0.082336
# Duration        -0.088113
# EndDayValue      0.099700
#  ClosePrice      0.999470
#  OpenPrice       0.472885
# Competitive      0.180872
# USDClosePrice    0.996906
# USDOpenPrice     0.474961
# DollarOpen       1.000000

# %%
sns.heatmap(ebay.corr());

# %%
sns.heatmap(ebay.corr())
plt.figure(figsize=(16, 6))
heatmap = sns.heatmap(ebay.corr(), vmin=-1, vmax=1, annot=True,cmap='BrBG')
heatmap.set_title('Correlation Heatmap', fontdict={'fontsize':12}, pad=12);
